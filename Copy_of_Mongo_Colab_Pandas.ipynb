# %% [markdown]
# <a href="https://colab.research.google.com/github/jlsgodev/dados/blob/main/Copy_of_Mongo_Colab_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo[srv]
# !pip install pandas
# Out:
# ...
# WARNING: pymongo 4.9.1 does not provide the extra 'srv'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.6 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# Conectar ao MongoDB Atlas usando a string de conexão com a senha correta
client = MongoClient("mongodb+srv://SEU_USUARIO:SUA_SENHA@cluster0.re9ch.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# Acessar o banco de dados. Substitua 'sample_mflix' pelo nome do seu banco de dados.
db = client['sample_mflix']

# Acessar a coleção. Substitua 'movies' pela coleção que você quer acessar.
collection = db['movies']

# Verificar a estrutura de um único documento (para inspeção)
document = collection.find_one()
print("Exemplo de documento da coleção:")
print(document)

# Buscar todos os documentos com um limite de 5 para evitar problemas com grandes volumes de dados
documents = collection.find().limit(5)

# Converter os documentos para uma lista
data = list(documents)

# Converter a lista de documentos para um DataFrame do Pandas
df = pd.DataFrame(data)

# Exibir o DataFrame
print("Primeiros documentos como DataFrame:")
# print(df.head())
display(df)
# Para extrair campos específicos, como 'title', 'year', 'genres', você pode fazer o seguinte:
documents_filtered = collection.find({}, {'title': 1, 'year': 1, 'genres': 1}).limit(5)

# Converter os documentos filtrados para uma lista
data_filtered = list(documents_filtered)

# Converter a lista filtrada para um DataFrame do Pandas
df_filtered = pd.DataFrame(data_filtered)

# Exibir o DataFrame filtrado
print("Documentos filtrados (apenas 'title', 'year', 'genres'):")
# print(df_filtered.head())

display(df_filtered)
# Out:
# Exemplo de documento da coleção:
# ...

# %%
import pandas as pd

# Exemplo de DataFrame
data = {
    'id': [1, 2, 3],
    'nome': ['Ana', 'Bruno', 'Carla'],
    'idade': [23, 35, 45],
    'salario': [5000.50, 7000.00, 8500.75],
    'ativo': [True, False, True]
}
df = pd.DataFrame(data)

# Mapeamento de tipos do Pandas para MySQL
def mapear_tipo_para_mysql(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_string_dtype(dtype):
        return 'VARCHAR(255)'  # Definir tamanho adequado
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'  # Padrão para outros tipos

# Gerar declaração de criação de tabela para MySQL
def gerar_sql_criacao_tabela(df, nome_tabela):
    colunas_sql = []
    for coluna in df.columns:
        tipo_mysql = mapear_tipo_para_mysql(df[coluna].dtype)
        colunas_sql.append(f"`{coluna}` {tipo_mysql}")

    colunas_sql_str = ",\n  ".join(colunas_sql)
    sql_criacao_tabela = f"CREATE TABLE `{nome_tabela}` (\n  {colunas_sql_str}\n);"
    return sql_criacao_tabela

# Exemplo de uso
nome_tabela = 'pessoas'
sql = gerar_sql_criacao_tabela(df, nome_tabela)
print(sql)

# %%
# CREATE TABLE `pessoas` (
#   `id` INT,
#   `nome` VARCHAR(255),
#   `idade` INT,
#   `salario` FLOAT,
#   `ativo` BOOLEAN
# );
